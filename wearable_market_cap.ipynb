# %%
from shared import *
purchases_df = get_wearable_purchases_df()
types_df = get_wearable_types_df()

# %%
last_price = purchases_df.groupby('erc1155TypeId').last(1)['price'].rename('lastPrice')
market_cap_df = types_df.join(last_price)
market_cap_df['marketCap'] = market_cap_df['lastPrice'] * market_cap_df['maxQuantity']
market_cap_df
# Out:
#                 name  maxQuantity  rarityScoreModifier  NRG  AGG  SPK  BRN  \
# id
# 1           Camo Hat         1000                    1    0    1    0    0
# 2         Camo Pants         1000                    1    0    1    0    0
# 3        MK2 Grenade         1000                    1    0    1    0    0
# 4      Snow Camo Hat          500                    2    0    1    1    0
# 5    Snow Camo Pants          500                    2    0    1    1    0
# ..               ...          ...                  ...  ...  ...  ...  ...
# 311     Spirit Sword           50                   20    2   -3    0    0
# 312     Plate Shield           50                   20    0   -5    0    0
# 313    Kabuto Helmet            5                   50    0    3    3    0
# 314      Yoroi Armor            5                   50    0    3    3    0
# 315    Haanzo Katana            5                   50    0    2    4    0
#
#     NRG Effect AGG Effect SPK Effect BRN Effect       slotNames    rarity  \
# id
# 1                       +                                  Head    common
# 2                       +                                  Body    common
# 3                       +                        Hand L, Hand R    common
# 4                       +          +                       Head  uncommon
# 5                       +          +                       Body  uncommon
# ..         ...        ...        ...        ...             ...       ...
# 311          +          -                        Hand L, Hand R  mythical
# 312                     -                        Hand L, Hand R  mythical
# 313                     +          +                       Head   godlike
# 314                     +          +                       Body   godlike
# 315                     +          +             Hand L, Hand R   godlike
#
#      lastPrice  marketCap
# id
# 1         14.0    14000.0
# 2         14.0    14000.0
# 3         44.0    44000.0
# 4         24.0    12000.0
# 5         31.0    15500.0
# ..         ...        ...
# 311     2111.0   105550.0
# 312     1998.0    99900.0
# 313    49089.0   245445.0
# 314    40000.0   200000.0
# 315    35000.0   175000.0
#
# [245 rows x 15 columns]

# %%
market_cap_df.head()
# Out:
#                name  maxQuantity  rarityScoreModifier  NRG  AGG  SPK  BRN  \
# id
# 1          Camo Hat         1000                    1    0    1    0    0
# 2        Camo Pants         1000                    1    0    1    0    0
# 3       MK2 Grenade         1000                    1    0    1    0    0
# 4     Snow Camo Hat          500                    2    0    1    1    0
# 5   Snow Camo Pants          500                    2    0    1    1    0
#
#    NRG Effect AGG Effect SPK Effect BRN Effect       slotNames    rarity  \
# id
# 1                      +                                  Head    common
# 2                      +                                  Body    common
# 3                      +                        Hand L, Hand R    common
# 4                      +          +                       Head  uncommon
# 5                      +          +                       Body  uncommon
#
#     lastPrice  marketCap
# id
# 1        14.0    14000.0
# 2        14.0    14000.0
# 3        44.0    44000.0
# 4        24.0    12000.0
# 5        31.0    15500.0

# %%
market_cap_df.describe()
# Out:
#        maxQuantity  rarityScoreModifier         NRG         AGG         SPK  \
# count   245.000000           245.000000  245.000000  245.000000  245.000000
# mean    337.200000            11.228571    0.028571    0.020408    0.053061
# std     331.646261            13.742837    1.542831    1.550909    1.280865
# min       5.000000             1.000000   -6.000000   -6.000000   -5.000000
# 25%     100.000000             2.000000    0.000000    0.000000    0.000000
# 50%     250.000000             5.000000    0.000000    0.000000    0.000000
# 75%     500.000000            10.000000    1.000000    1.000000    0.000000
# max    1000.000000            50.000000    6.000000    6.000000    5.000000
#
#               BRN      lastPrice      marketCap
# count  245.000000     237.000000     237.000000
# mean     0.122449    3931.454177   86025.946203
# std      1.446203   13689.561045   91145.996466
# min     -5.000000       8.950000    7500.000000
# 25%      0.000000      43.000000   30000.000000
# 50%      0.000000     270.000000   62375.000000
# 75%      0.000000    1299.000000  104995.000000
# max      6.000000  112000.000000  600000.000000

# %%
market_cap_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 245 entries, 1 to 315
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 245 non-null    object
#  1   maxQuantity          245 non-null    int64
#  2   rarityScoreModifier  245 non-null    int64
#  3   NRG                  245 non-null    int64
#  4   AGG                  245 non-null    int64
#  5   SPK                  245 non-null    int64
#  6   BRN                  245 non-null    int64
#  7   NRG Effect           245 non-null    object
#  8   AGG Effect           245 non-null    object
#  9   SPK Effect           245 non-null    object
#  10  BRN Effect           245 non-null    object
#  11  slotNames            245 non-null    object
#  12  rarity               245 non-null    object
#  13  lastPrice            237 non-null    float64
#  14  marketCap            237 non-null    float64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 38.7+ KB

# %%
market_cap_df.to_csv('db/wearable_market_cap.csv')
