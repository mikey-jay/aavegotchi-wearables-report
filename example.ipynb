# %%
from shared import *

# %%
query = get_core_matic_query(
    { 'aavegotchis': {
        'params': { 'first': 500, 'orderBy': 'withSetsRarityScore', 'orderDirection': 'desc', 'where': { 'status': 3 } },
        'fields': ["id", "gotchiId", "name", "withSetsRarityScore", "experience", "kinship"] }}
)

# %%
result = query.execute()

# %%
df = get_subgraph_result_df(result)
df
# Out:
#       gotchiId                name withSetsRarityScore experience kinship
# id
# 12518    12518        Diamond Eyes                 963        400     753
# 12611    12611           Rocinante                 915       1085     717
# 13700    13700             Godlike                 913       9940     740
# 19095    19095               Felon                 912       4070     735
# 13603    13603               auror                 900        100     584
# ...        ...                 ...                 ...        ...     ...
# 15434    15434             Syringa                 619       1105     755
# 9466      9466      Proof of Stake                 618       1665     934
# 8890      8890         Chill Magoo                 618       1175     592
# 7347      7347  Simone de Beauvoir                 618         40       3
# 406        406               Frens                 618        290     516
#
# [500 rows x 5 columns]
