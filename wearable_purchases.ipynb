# %%
from shared import *
purchases_df = get_wearable_purchases_df()

# %%
purchases_df.head()
# Out:
#                                                     listingID  erc1155TypeId  \
# id
# 145645_0xf09d1acbf092ec47970a2aa9e16bc658b2ecf1...     145645             13
# 145683_0x795f50722cf5ad82f78dda8dc8f7b235332977...     145683             76
# 145509_0x73b46a49e5f92480710b07be849500b772b6a9...     145509             41
# 132339_0x73b46a49e5f92480710b07be849500b772b6a9...     132339             37
# 145037_0x22886301cf7b3a7e3c275a4620add2b47e3240...     145037            149
#
#                                                     quantity  \
# id
# 145645_0xf09d1acbf092ec47970a2aa9e16bc658b2ecf1...         1
# 145683_0x795f50722cf5ad82f78dda8dc8f7b235332977...         1
# 145509_0x73b46a49e5f92480710b07be849500b772b6a9...         2
# 132339_0x73b46a49e5f92480710b07be849500b772b6a9...         1
# 145037_0x22886301cf7b3a7e3c275a4620add2b47e3240...         1
#
#                                                                timePurchased  \
# id
# ...

# %%
purchases_df.describe()
# Out:
#            listingID  erc1155TypeId      quantity          price
# count   31642.000000   31642.000000  31642.000000   31642.000000
# mean   219210.372796     159.617218      1.205960     265.440214
# std     56783.259671      88.102905      2.593352    1890.758271
# min       547.000000       1.000000      1.000000       0.600000
# 25%    173715.000000      82.000000      1.000000      22.500000
# 50%    209417.000000     156.000000      1.000000      40.900000
# 75%    269026.750000     231.000000      1.000000     129.000000
# max    325795.000000     315.000000    200.000000  112000.000000

# %%
purchases_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31642 entries, 145645_0xf09d1acbf092ec47970a2aa9e16bc658b2ecf15e_1629211076 to 325105_0xfc2ea617f5214fdb17caa576837cd044b93959b9_1660722768
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   listingID             31642 non-null  int64
#  1   erc1155TypeId         31642 non-null  int64
#  2   quantity              31642 non-null  int64
#  3   timePurchased         31642 non-null  datetime64[ns, UTC]
#  4   datePurchased         31642 non-null  object
#  5   startOfWeekPurchased  31642 non-null  object
#  6   yearMonthPurchased    31642 non-null  object
#  7   price                 31642 non-null  float128
# dtypes: datetime64[ns, UTC](1), float128(1), int64(3), object(3)
# memory usage: 2.4+ MB
